# %%
 import pandas as pd
 import numpy as np
 from sklearn.model_selection import train_test_split
 from sklearn.impute import SimpleImputer
 import matplotlib.pyplot as plt
 import seaborn as sns
 from pylab import rcParams

# %%
df=pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.shape
# Out:
# (1338, 7)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# prompt: when do l use randomforest algorithm

# You can use the random forest algorithm when:
# - You have a large dataset.
# - Your data has many features.
# - Your data is non-linear.
# - You want to build a model that is robust to noise and outliers.
# - You want to build a model that is easy to interpret.

# To use the random forest algorithm in Python, you can use the `sklearn.ensemble.RandomForestClassifier` class.

# Here is an example of how to use the random forest algorithm to classify the data in the `df` dataframe:

from sklearn.ensemble import RandomForestClassifier

# Create a random forest classifier.
clf = RandomForestClassifier()

# Fit the classifier to the data.
clf.fit(df.drop('Outcome', axis=1), df['Outcome'])

# Predict the outcome for new data.
predictions = clf.predict(new_data)

# %%
# prompt: how do l convert column sex and smoker to numeric

df['sex'] = df['sex'].replace({'female': 0, 'male': 1})
df['smoker'] = df['smoker'].replace({'yes': 1, 'no': 0})

# %%
df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# prompt: how to  visualise all male smokers

import matplotlib.pyplot as plt
sns.lmplot(x='age', y='charges', data=df, hue='sex', col='smoker', palette='Set1')
plt.show()

# %%
df.plot()
# Out:
# <Axes: >

# %%
sns.displot(df, x="age", hue="sex")
